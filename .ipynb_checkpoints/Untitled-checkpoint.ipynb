# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./CARS_1.csv')

# %%
df.head()
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
#
#    body_type  rating  starting_price  ending_price  max_torque_nm  \
# ...

# %%
df['transmission_type'].unique()
# Out:
# array(['Automatic', 'Manual', 'Electric'], dtype=object)

# %%
df.corr()
# Out:
#                      reviews_count  engine_displacement  no_cylinder  \
# reviews_count             1.000000            -0.198252    -0.131809
# engine_displacement      -0.198252             1.000000     0.948265
# no_cylinder              -0.131809             0.948265     1.000000
# seating_capacity          0.081227            -0.278781    -0.290952
# fuel_tank_capacity       -0.007323             0.403951     0.381672
# rating                    0.021518            -0.040186    -0.089962
# starting_price           -0.217540             0.622474     0.580439
# ending_price             -0.215838             0.634447     0.593383
# max_torque_nm            -0.272184             0.678812     0.615500
# max_torque_rpm           -0.026057             0.399129     0.474884
# max_power_bhp            -0.280433             0.723541     0.686595
# max_power_rp             -0.003046             0.427978     0.523751
#
# ...

# %%
sns.catplot(x = 'no_cylinder', kind = 'count', data = df)

# %%
for i in df.columns:
    sns.catplot(x = i,kind = 'count',data = df,palette = 'pastel')
    plt.gcf().set_size_inches(25,8)

# %%
df.head()
# Out:
#              car_name  reviews_count fuel_type  engine_displacement  \
# 0     Maruti Alto K10             51    Petrol                  998
# 1       Maruti Brezza             86    Petrol                 1462
# 2       Mahindra Thar            242    Diesel                 2184
# 3     Mahindra XUV700            313    Diesel                 2198
# 4  Mahindra Scorpio-N            107    Diesel                 2198
#
#    no_cylinder  seating_capacity transmission_type  fuel_tank_capacity  \
# 0            3               5.0         Automatic                27.0
# 1            4               5.0         Automatic                48.0
# 2            4               4.0         Automatic                57.0
# 3            4               7.0         Automatic                60.0
# 4            4               7.0         Automatic                57.0
#
#    body_type  rating  starting_price  ending_price  max_torque_nm  \
# ...

# %%
df['transmission_type'].unique()
# Out:
# array(['Automatic', 'Manual', 'Electric'], dtype=object)

# %%
df.groupby('fuel_type')['starting_price'].mean().reset_index().round()
# Out:
#   fuel_type  starting_price
# 0       CNG       3975714.0
# 1    Diesel       5111782.0
# 2  Electric      12224812.0
# 3    Petrol      11299872.0

# %%
df['body_type'].unique()
# Out:
# array(['Hatchback', 'SUV', 'MUV', 'Sedan', 'Hybrid', 'Minivan',
#        'Pickup Truck', 'Coupe', 'Convertible', 'Luxury', 'Wagon'],
#       dtype=object)

# %%
df.columns.drop(['car_name','fuel_type','transmission_type','body_type']).tolist()
# Out:
# ['reviews_count',
#  'engine_displacement',
#  'no_cylinder',
#  'seating_capacity',
#  'fuel_tank_capacity',
#  'rating',
#  'starting_price',
#  'ending_price',
#  'max_torque_nm',
#  'max_torque_rpm',
#  'max_power_bhp',
#  'max_power_rp']

# %%
df.groupby(df['fuel_type'])['reviews_count'].mean()
# Out:
# fuel_type
# CNG         227.428571
# Diesel      232.127273
# Electric      8.187500
# Petrol       76.824000
# Name: reviews_count, dtype: float64

# %%
for i in df.columns.drop(['car_name','fuel_type','transmission_type','body_type']):
    df.groupby(df['fuel_type'])[i].mean().plot()

# %%
df.columns[0]
# Out:
# 'car_name'

# %%
df_num = df.drop(['car_name','fuel_type','transmission_type','body_type'],axis = 1)
df_num.head()
# Out:
#    reviews_count  engine_displacement  no_cylinder  seating_capacity  \
# 0             51                  998            3               5.0
# 1             86                 1462            4               5.0
# 2            242                 2184            4               4.0
# 3            313                 2198            4               7.0
# 4            107                 2198            4               7.0
#
#    fuel_tank_capacity  rating  starting_price  ending_price  max_torque_nm  \
# 0                27.0     4.5          399000        583000           89.0
# 1                48.0     4.5          799000       1396000          136.8
# 2                57.0     4.5         1353000       1603000          300.0
# 3                60.0     4.5         1318000       2458000          450.0
# 4                57.0     4.5         1199000       2390000          400.0
#
#    max_torque_rpm  max_power_bhp  max_power_rp
# 0            3500          65.71          5500
# ...

# %%
df_num.columns[0]
# Out:
# 'reviews_count'

# %%
for i in range(12):
    df_group = df.groupby(df['fuel_type'])[df_num.columns[i]].mean().reset_index()
    df_group

# %%
df_ff = df.groupby(df['fuel_type'])[df_num.columns[4]].mean().reset_index()

# %%
df_ff.head()
# Out:
#   fuel_type  fuel_tank_capacity
# 0       CNG           56.428571
# 1    Diesel           51.081818
# 2  Electric            0.000000
# 3    Petrol           49.301600

# %%
sns.barplot(data = df.groupby(df['fuel_type'])[df_num.columns[4]].mean().reset_index(),
           x = 'fuel_type',
           y = 'fuel_tank_capacity')
plt.gcf().set_size_inches(12,8)

# %%
f,ax = plt.subplots(3,4,figsize = (12,10),constrained_layout=True)
for i in range(1,12):
    plt.subplot(3,4,i)
    sns.barplot(data = df.groupby(df['fuel_type'])[df_num.columns[i]].mean().reset_index(),
           x = 'fuel_type',
           y = df_num.columns[i])
    plt.ylabel('')
    plt.title(df_num.columns[i])
    #plt.gcf().set_size_inches(12,8)
    #plt.show()

# %%
f,ax = plt.subplots(3,4,figsize = (12,10),constrained_layout=True)
for i in range(1,12):
    plt.subplot(3,4,i)
    sns.barplot(data = df.groupby(df['transmission_type'])[df_num.columns[i]].mean().reset_index(),
           x = 'transmission_type',
           y = df_num.columns[i])
    plt.ylabel('')
    plt.title(df_num.columns[i])
    #plt.gcf().set_size_inches(12,8)
    #plt.show()

# %%
plt.figure(figsize = (12,10),constrained_layout=True)
subplot = 1
for i in listNum: 
    plt.subplot(3,5,subplot)
    #sns.histplot(data=df, x=i)
    sns.barplot(data = df.groupby(df['transmission_type'])[i].mean().reset_index(),
           x = 'transmission_type',
           y = i)
    subplot = subplot +1
    plt.ylabel('')
plt.show()

# %%
listNum = df_num.columns
